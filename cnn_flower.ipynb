# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from random import shuffle

# %%
#model selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
#preprocess.
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# specifically for cnn
import tensorflow as tf
from tensorflow.keras.layers import Flatten,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %%
class_names=['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='image of flower/flowers/daisy'
FLOWER_SUNFLOWER_DIR='image of flower/flowers/sunflower'
FLOWER_TULIP_DIR='image of flower/flowers/tulip'
FLOWER_DANDI_DIR='image of flower/flowers/dandelion'
FLOWER_ROSE_DIR='image of flower/flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
import cv2
from tqdm import tqdm
import os

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 764/764 [00:16<00:00, 47.02it/s]
# 764

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|██████████| 733/733 [00:10<00:00, 72.89it/s]
# 1497

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|██████████| 984/984 [00:17<00:00, 55.71it/s]
# 2481

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 1052/1052 [00:18<00:00, 56.81it/s]
# 3533

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:15<00:00, 49.22it/s]
# 4317

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """

    index = np.random.randint(len(labels))
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(True)
    plt.title('Image #{} : '.format(index) + labels[index])
    plt.show()

# %%
display_random_image(class_names, X, Z)

# %%
Z[800]
# Out:
# 'Sunflower'

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (3237, 150, 150, 3)

# %%
np.random.seed(42)

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "softmax"))

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
datagen.fit(x_train)

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 7776)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3981824
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,143,749
# Trainable params: 4,143,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# WARNING:tensorflow:From <ipython-input-26-d6c7731ea050>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 25/25 [==============================] - 142s 6s/step - loss: 1.4523 - accuracy: 0.3561 - val_loss: 1.1550 - val_accuracy: 0.4852
# Epoch 2/50
# 25/25 [==============================] - 104s 4s/step - loss: 1.1960 - accuracy: 0.4796 - val_loss: 1.0636 - val_accuracy: 0.5426
# Epoch 3/50
# 25/25 [==============================] - 97s 4s/step - loss: 1.1146 - accuracy: 0.5442 - val_loss: 1.0614 - val_accuracy: 0.5593
# Epoch 4/50
# 25/25 [==============================] - 99s 4s/step - loss: 1.0403 - accuracy: 0.5918 - val_loss: 0.9217 - val_accuracy: 0.6463
# Epoch 5/50
# 25/25 [==============================] - 98s 4s/step - loss: 1.0084 - accuracy: 0.6091 - val_loss: 0.8921 - val_accuracy: 0.6491
# Epoch 6/50
# 25/25 [==============================] - 102s 4s/step - loss: 0.9217 - accuracy: 0.6410 - val_loss: 0.8549 - val_accuracy: 0.6528
# Epoch 7/50
# 25/25 [==============================] - 100s 4s/step - loss: 0.8938 - accuracy: 0.6597 - val_loss: 0.8275 - val_accuracy: 0.6676
# Epoch 8/50
# 25/25 [==============================] - 91s 4s/step - loss: 0.8647 - accuracy: 0.6658 - val_loss: 0.8684 - val_accuracy: 0.6463
# Epoch 9/50
# 25/25 [==============================] - 96s 4s/step - loss: 0.8189 - accuracy: 0.6748 - val_loss: 0.7701 - val_accuracy: 0.6963
# Epoch 10/50
# 25/25 [==============================] - 102s 4s/step - loss: 0.8195 - accuracy: 0.6867 - val_loss: 0.7638 - val_accuracy: 0.7065
# Epoch 11/50
# 25/25 [==============================] - 108s 4s/step - loss: 0.7904 - accuracy: 0.6909 - val_loss: 0.7406 - val_accuracy: 0.7157
# Epoch 12/50
# 25/25 [==============================] - 96s 4s/step - loss: 0.7585 - accuracy: 0.7073 - val_loss: 0.7749 - val_accuracy: 0.7037
# Epoch 13/50
# 25/25 [==============================] - 92s 4s/step - loss: 0.7522 - accuracy: 0.7092 - val_loss: 0.7574 - val_accuracy: 0.7037
# Epoch 14/50
# 25/25 [==============================] - 90s 4s/step - loss: 0.7219 - accuracy: 0.7263 - val_loss: 0.6859 - val_accuracy: 0.7306
# Epoch 15/50
# 25/25 [==============================] - 117s 5s/step - loss: 0.7251 - accuracy: 0.7195 - val_loss: 0.6968 - val_accuracy: 0.7194
# Epoch 16/50
# 25/25 [==============================] - 98s 4s/step - loss: 0.6781 - accuracy: 0.7488 - val_loss: 0.6402 - val_accuracy: 0.7435
# Epoch 17/50
# 25/25 [==============================] - 106s 4s/step - loss: 0.6660 - accuracy: 0.7398 - val_loss: 0.6722 - val_accuracy: 0.7444
# Epoch 18/50
# 25/25 [==============================] - 102s 4s/step - loss: 0.6351 - accuracy: 0.7600 - val_loss: 0.6801 - val_accuracy: 0.7463
# Epoch 19/50
# 25/25 [==============================] - 96s 4s/step - loss: 0.6197 - accuracy: 0.7649 - val_loss: 0.6725 - val_accuracy: 0.7407
# Epoch 20/50
# 25/25 [==============================] - 102s 4s/step - loss: 0.6226 - accuracy: 0.7684 - val_loss: 0.7286 - val_accuracy: 0.7287
# Epoch 21/50
# 25/25 [==============================] - 102s 4s/step - loss: 0.6322 - accuracy: 0.7575 - val_loss: 0.6194 - val_accuracy: 0.7694
# Epoch 22/50
# 25/25 [==============================] - 104s 4s/step - loss: 0.5936 - accuracy: 0.7739 - val_loss: 0.6286 - val_accuracy: 0.7685
# Epoch 23/50
# 25/25 [==============================] - 102s 4s/step - loss: 0.6021 - accuracy: 0.7652 - val_loss: 0.6814 - val_accuracy: 0.7481
# Epoch 24/50
# 25/25 [==============================] - 97s 4s/step - loss: 0.5771 - accuracy: 0.7777 - val_loss: 0.5821 - val_accuracy: 0.7713
# Epoch 25/50
# 25/25 [==============================] - 95s 4s/step - loss: 0.5332 - accuracy: 0.8054 - val_loss: 0.6904 - val_accuracy: 0.7444
# Epoch 26/50
# 25/25 [==============================] - 104s 4s/step - loss: 0.5696 - accuracy: 0.7819 - val_loss: 0.5924 - val_accuracy: 0.7704
# Epoch 27/50
# 25/25 [==============================] - 92s 4s/step - loss: 0.5302 - accuracy: 0.7961 - val_loss: 0.7134 - val_accuracy: 0.7472
# Epoch 28/50
# 25/25 [==============================] - 88s 4s/step - loss: 0.5555 - accuracy: 0.7913 - val_loss: 0.5797 - val_accuracy: 0.7759
# Epoch 29/50
# 25/25 [==============================] - 83s 3s/step - loss: 0.5474 - accuracy: 0.7964 - val_loss: 0.5753 - val_accuracy: 0.7917
# Epoch 30/50
# 25/25 [==============================] - 88s 4s/step - loss: 0.4980 - accuracy: 0.8067 - val_loss: 0.5857 - val_accuracy: 0.7972
# Epoch 31/50
# 25/25 [==============================] - 77s 3s/step - loss: 0.5091 - accuracy: 0.8089 - val_loss: 0.5565 - val_accuracy: 0.7963
# Epoch 32/50
# 25/25 [==============================] - 85s 3s/step - loss: 0.4709 - accuracy: 0.8221 - val_loss: 0.6666 - val_accuracy: 0.7667
# Epoch 33/50
# 25/25 [==============================] - 81s 3s/step - loss: 0.4691 - accuracy: 0.8321 - val_loss: 0.5821 - val_accuracy: 0.7954
# Epoch 34/50
# 25/25 [==============================] - 89s 4s/step - loss: 0.4768 - accuracy: 0.8150 - val_loss: 0.5904 - val_accuracy: 0.7843
# Epoch 35/50
# 25/25 [==============================] - 86s 3s/step - loss: 0.4653 - accuracy: 0.8292 - val_loss: 0.5526 - val_accuracy: 0.7917
# Epoch 36/50
# 25/25 [==============================] - 83s 3s/step - loss: 0.4533 - accuracy: 0.8311 - val_loss: 0.5676 - val_accuracy: 0.8019
# Epoch 37/50
# 25/25 [==============================] - 82s 3s/step - loss: 0.4458 - accuracy: 0.8356 - val_loss: 0.6168 - val_accuracy: 0.7843
# Epoch 38/50
# 25/25 [==============================] - 85s 3s/step - loss: 0.4259 - accuracy: 0.8376 - val_loss: 0.6945 - val_accuracy: 0.7648
# Epoch 39/50
# 25/25 [==============================] - 87s 3s/step - loss: 0.4003 - accuracy: 0.8479 - val_loss: 0.5972 - val_accuracy: 0.7889
# Epoch 40/50
# 25/25 [==============================] - 88s 4s/step - loss: 0.4172 - accuracy: 0.8430 - val_loss: 0.5865 - val_accuracy: 0.7972
# Epoch 41/50
# 25/25 [==============================] - 79s 3s/step - loss: 0.3874 - accuracy: 0.8508 - val_loss: 0.6184 - val_accuracy: 0.7926
# Epoch 42/50
# 25/25 [==============================] - 90s 4s/step - loss: 0.3554 - accuracy: 0.8713 - val_loss: 0.5543 - val_accuracy: 0.8093
# Epoch 43/50
# 25/25 [==============================] - 98s 4s/step - loss: 0.3718 - accuracy: 0.8627 - val_loss: 0.5649 - val_accuracy: 0.7972
# Epoch 44/50
# 25/25 [==============================] - 86s 3s/step - loss: 0.3955 - accuracy: 0.8501 - val_loss: 0.6093 - val_accuracy: 0.7778
# Epoch 45/50
# 25/25 [==============================] - 93s 4s/step - loss: 0.3421 - accuracy: 0.8701 - val_loss: 0.5450 - val_accuracy: 0.8148
# Epoch 46/50
# 25/25 [==============================] - 80s 3s/step - loss: 0.3487 - accuracy: 0.8662 - val_loss: 0.5905 - val_accuracy: 0.8056
# Epoch 47/50
# 25/25 [==============================] - 83s 3s/step - loss: 0.3567 - accuracy: 0.8659 - val_loss: 0.5724 - val_accuracy: 0.8102
# Epoch 48/50
# 25/25 [==============================] - 83s 3s/step - loss: 0.3156 - accuracy: 0.8820 - val_loss: 0.6261 - val_accuracy: 0.7963
# Epoch 49/50
# 25/25 [==============================] - 89s 4s/step - loss: 0.3679 - accuracy: 0.8636 - val_loss: 0.5443 - val_accuracy: 0.8204
# Epoch 50/50
# 25/25 [==============================] - 80s 3s/step - loss: 0.3236 - accuracy: 0.8820 - val_loss: 0.6016 - val_accuracy: 0.8074

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
# getting predictions on val set.
pred=model.predict(x_test)
pred_digits=np.argmax(pred,axis=1)
test_digits = np.argmax(y_test,axis=1)

# %%
print("Accuracy : {}".format(accuracy_score(test_digits, pred_digits)))
# Out:
# Accuracy : 0.8074074074074075

# %%
pred_labels = le.inverse_transform(pred_digits)

# %%
display_random_image(class_names, x_test, pred_labels)

# %%
model.save('FlowerClassification.h5')

# %%
img = cv2.imread('rose-165819__480.jpg',cv2.IMREAD_COLOR)
img = cv2.resize(img, (150,150))
a=np.array(img)
a=a/255
a=a.reshape(1,150,150,3)

# %%
p=model.predict(a)
np.argmax(p[0])
# Out:
# 2

# %%
label={0:'Daisy',1:'Dandelion',2:'Rose',3:'Sunflower',4:'Tulip'}
label[2]
# Out:
# 'Rose'

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """

    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, x_test, test_digits, pred_digits)

# %%
CM = confusion_matrix(test_digits, pred_digits)
ax = plt.axes()
sns.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()
